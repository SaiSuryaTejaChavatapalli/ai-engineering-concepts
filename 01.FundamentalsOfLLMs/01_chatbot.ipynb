# %% [markdown]
# # A model, stripped to its essence
#
# Forget chat windows and personalities for a moment. Underneath everything, a langauge model is one thing; a function that receives some text and hands back some text. It runs once, produces its answer, and holds on to nothing. Ask it something a second time and it has no clue it ever met you

# %%
def stateless_reply(prompt: str)-> str:
    return f"some llm response mimicking the models output: {prompt}"

print(stateless_reply("Who is the PM of UK"))

print(stateless_reply("Who was before him?"))
# Out:
# some llm response mimicking the models output: Who is the PM of UK
# some llm response mimicking the models output: Who was before him?

# %%
def stateless_chatgpt_demo(prompt: str) -> str:
    from dotenv import load_dotenv
    from openai import OpenAI
    load_dotenv()

    client=OpenAI()

    response= client.responses.create(
        model="gpt-4o-mini",
        input=prompt
    )
    return response.output_text

# %%
stateless_chatgpt_demo("WHo was the PM of UK before 2020")
# Out:
# 'Before 2020, the Prime Minister of the United Kingdom was Theresa May. She served from July 13, 2016, until July 24, 2019. After her resignation, Boris Johnson became Prime Minister.'

# %%
stateless_chatgpt_demo("WHo was before him?")
# Out:
# 'Could you please clarify who "him" refers to? This will help me provide a more accurate answer.'
